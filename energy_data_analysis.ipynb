# %%
# import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset from a CSV file
file_name = 'simulated_energy_data.csv'
data = pd.read_csv(file_name)

# %%
# display the DataFrame's information and first few rows
print(data.info())
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8737 entries, 0 to 8736
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               8737 non-null   object
#  1   Energy_Consumption_kWh  8737 non-null   float64
#  2   Temperature_F           8737 non-null   float64
#  3   Humidity_%              8737 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 273.2+ KB
# None
#              Timestamp  Energy_Consumption_kWh  Temperature_F  Humidity_%
# 0  2023-01-01 00:00:00                6.996316      61.241241   31.629240
# 1  2023-01-01 01:00:00               12.989297      28.549153   47.852641
# 2  2023-01-01 02:00:00               11.406376      34.034921   41.688344
# 3  2023-01-01 03:00:00               13.826586      57.490288   38.079370
# 4  2023-01-01 04:00:00                7.974294      44.710598   81.039402

# %%
# display a statistical summary of the DataFrame
print(data.describe())
# Out:
#        Energy_Consumption_kWh  Temperature_F   Humidity_%
# count             8737.000000    8737.000000  8737.000000
# mean                10.029021      50.310800    59.992466
# std                  2.894198      17.389676    17.386601
# min                  5.000019      20.001442    30.000482
# 25%                  7.538616      35.218777    44.763313
# 50%                 10.033336      50.714660    59.978673
# 75%                 12.533653      65.282277    75.088031
# max                 14.999847      79.998054    89.995616

# %% [markdown]
# Note the set ranges
# energy consumtpion: 5-15
# temp: 20 - 80
# humidity %: 30 to 90

# %%
# histograms to explore data distributions
data.hist(bins=30, figsize=(10, 7))
plt.tight_layout()
plt.show()

# %%
# line plot for energy consumption over time
plt.figure(figsize=(10, 5))
plt.plot(data['Timestamp'], data['Energy_Consumption_kWh'], label='Energy Consumption')
plt.xlabel('Time')
plt.ylabel('Energy Consumption (kWh)')
plt.title('Energy Consumption Over Time')
plt.legend()
plt.show()
